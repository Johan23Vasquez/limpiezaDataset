# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
from datetime import datetime

# %%
archivo_Torre2 = "../data/raw/002_Torre2.csv"
torre = pd.read_csv(archivo_Torre2, index_col=0, parse_dates=True)

archivo_mayo = "../data/raw/29-may-2026.csv"
may = pd.read_csv(archivo_mayo, encoding='ISO-8859-1',index_col=11, parse_dates=True)
may.index
# Out:
# C:\Users\atlas\AppData\Local\Temp\ipykernel_21008\113621073.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   may = pd.read_csv(archivo_mayo, encoding='ISO-8859-1',index_col=11, parse_dates=True)
# DatetimeIndex(['2026-05-25 13:53:37', '2026-05-25 13:54:37',
#                '2026-05-25 13:55:37', '2026-05-25 13:56:37',
#                '2026-05-25 13:57:37', '2026-05-25 13:58:37',
#                '2026-05-25 13:59:37', '2026-05-25 14:00:37',
#                '2026-05-25 14:01:37', '2026-05-25 14:02:37',
#                ...
#                '2026-05-29 08:53:37', '2026-05-29 08:54:37',
#                '2026-05-29 08:55:37', '2026-05-29 08:56:37',
#                '2026-05-29 08:57:37', '2026-05-29 08:58:37',
#                '2026-05-29 08:59:37', '2026-05-29 09:00:37',
#                '2026-05-29 09:01:37', '2026-05-29 09:02:37'],
# ...

# %%
torre.index = pd.to_datetime(torre.index, format="mixed", utc=True)

# %%
concatenado = pd.concat(
    [torre, may]
)

# %%
concatenado.head()
# Out:
#                                     T03    T04    T05    T06    T07    T08  \
# 2026-05-27 06:00:14.504000+00:00  24.51  24.37  24.36  24.11  23.83  23.70
# 2026-05-27 06:00:34.409000+00:00  24.56  24.42  24.33  24.08  23.86  23.72
# 2026-05-27 06:00:54.314000+00:00  24.57  24.38  24.32  23.95  23.78  23.54
# 2026-05-27 06:01:14.222000+00:00  24.44  24.17  24.18  23.92  23.62  23.52
# 2026-05-27 06:01:34.126000+00:00  24.33  24.10  24.07  23.88  23.60  23.43
#
#                                     T01    T02  Lectura  Descripción  \
# 2026-05-27 06:00:14.504000+00:00  24.79  24.95      NaN          NaN
# 2026-05-27 06:00:34.409000+00:00  24.74  24.88      NaN          NaN
# 2026-05-27 06:00:54.314000+00:00  24.76  24.88      NaN          NaN
# 2026-05-27 06:01:14.222000+00:00  24.72  24.91      NaN          NaN
# 2026-05-27 06:01:34.126000+00:00  24.68  24.78      NaN          NaN
#
#                                  Temperatura Bulbo húmedo  \
# ...
